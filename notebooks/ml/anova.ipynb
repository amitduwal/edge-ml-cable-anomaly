# %%
import h5py
import numpy as np

# %%
mat_file = r'E:\Thesis\thesis_code\data\rp\100Mbps_features.h5'   # change path

# %%
with h5py.File(mat_file, 'r') as f:
    X = np.array(f['features'])          # Features
    y = np.array(f['label_type'])        # Labels
    z = np.array(f['label_length'])     # Length labels (if needed)

print("Feature shape:", X.shape)
print("Label shape:", y.shape)
# Out:
# Feature shape: (39525, 30)
# Label shape: (39525,)

# %%
X.shape[0]
# Out:
# 39525

# %%
import pandas as pd
from sklearn.feature_selection import f_classif

# %%
# ANOVA feature ranking
f_scores, p_values = f_classif(X, y)

# %%
# Create ranking table
feature_ranking = pd.DataFrame({
    "Feature": [f"F{i+1}" for i in range(X.shape[1])],
    "F_score": f_scores,
    "p_value": p_values
})

feature_ranking = feature_ranking.sort_values(
    by="F_score",
    ascending=False
)

print(feature_ranking)
# Out:
#    Feature       F_score        p_value
# 5       F6  44094.358056   0.000000e+00
# 10     F11  32439.969133   0.000000e+00
# 0       F1  32174.335320   0.000000e+00
# 2       F3  32156.461846   0.000000e+00
# 18     F19  29418.303081   0.000000e+00
# 14     F15  29388.583693   0.000000e+00
# 16     F17  28760.571784   0.000000e+00
# 12     F13  27674.490954   0.000000e+00
# 26     F27  25925.237913   0.000000e+00
# 20     F21  25736.655075   0.000000e+00
# 24     F25  23820.670694   0.000000e+00
# 3       F4  23119.693093   0.000000e+00
# 22     F23  19943.977870   0.000000e+00
# 28     F29  19491.395964   0.000000e+00
# 29     F30  12870.608930   0.000000e+00
# 1       F2  11952.179642   0.000000e+00
# 8       F9  11605.282826   0.000000e+00
# 7       F8  10000.709166   0.000000e+00
# 4       F5   9187.566247   0.000000e+00
# 25     F26   8272.436946   0.000000e+00
# 9      F10   7019.596603   0.000000e+00
# 27     F28   6607.484620   0.000000e+00
# 23     F24   3807.230989   0.000000e+00
# 17     F18   1763.944983   0.000000e+00
# 15     F16   1206.714919   0.000000e+00
# 21     F22    903.671657   0.000000e+00
# 13     F14    864.548043   0.000000e+00
# 6       F7    593.907253   0.000000e+00
# 19     F20    512.843392   0.000000e+00
# 11     F12    215.012161  2.326839e-138

# %%
feature_names = [
    # Time-domain features
    "std",
    "skewness",
    "rms",
    "mean",
    "kurtosis",
    "peak",
    "shape_factor",
    "impulse_factor",
    "crest_factor",
    "clearance_factor",

    # Frequency-domain features
    "freq_mag_0",
    "freq_val_0",
    "freq_mag_1",
    "freq_val_1",
    "freq_mag_2",
    "freq_val_2",
    "freq_mag_3",
    "freq_val_3",
    "freq_mag_4",
    "freq_val_4",
    "freq_mag_5",
    "freq_val_5",
    "freq_mag_6",
    "freq_val_6",
    "freq_mag_7",
    "freq_val_7",
    "freq_mag_8",
    "freq_val_8",
    "freq_mag_9",
    "freq_val_9",
]

f_scores, p_values = f_classif(X, y)

feature_ranking = pd.DataFrame({
    "Feature": feature_names,
    "F_score": f_scores,
    "p_value": p_values
})

feature_ranking = feature_ranking.sort_values(
    by="F_score",
    ascending=False
)

print("\n=== ANOVA Feature Ranking ===")
print(feature_ranking.to_string(index=False))

# Top 10 features only
print("\n=== Top 10 Features ===")
print(feature_ranking.head(10).to_string(index=False))
# Out:
# === ANOVA Feature Ranking ===
#          Feature      F_score       p_value
#             peak 44094.358056  0.000000e+00
#       freq_mag_0 32439.969133  0.000000e+00
#              std 32174.335320  0.000000e+00
#              rms 32156.461846  0.000000e+00
#       freq_mag_4 29418.303081  0.000000e+00
#       freq_mag_2 29388.583693  0.000000e+00
#       freq_mag_3 28760.571784  0.000000e+00
#       freq_mag_1 27674.490954  0.000000e+00
#       freq_mag_8 25925.237913  0.000000e+00
#       freq_mag_5 25736.655075  0.000000e+00
#       freq_mag_7 23820.670694  0.000000e+00
#             mean 23119.693093  0.000000e+00
#       freq_mag_6 19943.977870  0.000000e+00
#       freq_mag_9 19491.395964  0.000000e+00
#       freq_val_9 12870.608930  0.000000e+00
#         skewness 11952.179642  0.000000e+00
#     crest_factor 11605.282826  0.000000e+00
#   impulse_factor 10000.709166  0.000000e+00
#         kurtosis  9187.566247  0.000000e+00
#       freq_val_7  8272.436946  0.000000e+00
# clearance_factor  7019.596603  0.000000e+00
#       freq_val_8  6607.484620  0.000000e+00
#       freq_val_6  3807.230989  0.000000e+00
#       freq_val_3  1763.944983  0.000000e+00
#       freq_val_2  1206.714919  0.000000e+00
#       freq_val_5   903.671657  0.000000e+00
#       freq_val_1   864.548043  0.000000e+00
#     shape_factor   593.907253  0.000000e+00
#       freq_val_4   512.843392  0.000000e+00
#       freq_val_0   215.012161 2.326839e-138
#
# === Top 10 Features ===
#    Feature      F_score  p_value
#       peak 44094.358056      0.0
# freq_mag_0 32439.969133      0.0
#        std 32174.335320      0.0
#        rms 32156.461846      0.0
# freq_mag_4 29418.303081      0.0
# freq_mag_2 29388.583693      0.0
# freq_mag_3 28760.571784      0.0
# freq_mag_1 27674.490954      0.0
# freq_mag_8 25925.237913      0.0
# freq_mag_5 25736.655075      0.0

# %%
# 1. Define time-domain feature names in order of extraction
time_features = [
    'std', 
    'skewness', 
    'rms', 
    'mean', 
    'kurtosis', 
    'peak',
    'shape_factor', 
    'impulse_factor', 
    'crest_factor', 
    'clearance_factor'
]

# 2. Define frequency-domain feature names (interleaved magnitude and value for top 10 harmonics)
freq_features = []
for i in range(10):
    freq_features.append(f'freq_mag_{i}')
    freq_features.append(f'freq_val_{i}')

# 3. Combine into a single ordered list
feature_names = time_features + freq_features

# 4. Create the 0-29 index map dictionary
feature_map = {idx: name for idx, name in enumerate(feature_names)}

# Verification: Print the map
print("Index Map of Features:")
for idx, name in feature_map.items():
    print(f"{idx:2d} -> {name}")
# Out:
# Index Map of Features:
#  0 -> std
#  1 -> skewness
#  2 -> rms
#  3 -> mean
#  4 -> kurtosis
#  5 -> peak
#  6 -> shape_factor
#  7 -> impulse_factor
#  8 -> crest_factor
#  9 -> clearance_factor
# 10 -> freq_mag_0
# 11 -> freq_val_0
# 12 -> freq_mag_1
# 13 -> freq_val_1
# 14 -> freq_mag_2
# 15 -> freq_val_2
# 16 -> freq_mag_3
# 17 -> freq_val_3
# 18 -> freq_mag_4
# 19 -> freq_val_4
# 20 -> freq_mag_5
# 21 -> freq_val_5
# 22 -> freq_mag_6
# 23 -> freq_val_6
# 24 -> freq_mag_7
# 25 -> freq_val_7
# 26 -> freq_mag_8
# 27 -> freq_val_8
# 28 -> freq_mag_9
# 29 -> freq_val_9
