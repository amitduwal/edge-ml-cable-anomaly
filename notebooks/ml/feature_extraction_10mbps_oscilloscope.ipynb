# %%
import numpy as np
import matplotlib.pyplot as plt

import h5py
import os
from pathlib import Path

from enum import Enum
import re

from scipy.stats import skew, kurtosis
from scipy.fft import fft, fftfreq

# %%
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_1_2500.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_2501_5000.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_5001_7500.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_7501_10000.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_10001_12500.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_5cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_10cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_15cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_20cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_25cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_30cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_35cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_40cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_45cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_50cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_5cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_10cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_15cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_20cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_25cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_30cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_35cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_40cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_45cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_50cm.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_0.5m.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1m.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1.5m.mat'
# mat_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_2m.mat'

# %%
# with h5py.File(mat_file, 'r') as f:
#     reference_packet = np.array(f['packets'])  # shape: (recordLength,)
#     # Access metadata
    
#     metadata = f['metadata']
#     sample_rate = metadata['sample_rate'][0][0]
#     trigger_level = metadata['trigger_level'][0][0]
#     record_length = metadata['record_length'][0][0]
#     num_frames = metadata['num_frames'][0][0]

# print(f"Sample Rate: {sample_rate} Hz")
# print(f"Trigger Level: {trigger_level} V")
# print(f"Record Length: {record_length} samples")
# print(f"Number of Frames: {num_frames}")

# %% [markdown]
# ### Exract Signal Region

# %%
def extract_signal_region(signal, threshold=0.1):
    """Trims the quiet parts of the signal before and after the packet."""
    active = np.abs(signal) > threshold
    indices = np.where(active)[0]
    if indices.size == 0:
        return np.array([])
    return signal[indices[0] : indices[-1] + 1]

# %% [markdown]
# ### Ideal Packet Length

# %%
sample_rate = 1.25e9  # 1.25GHz
samples_per_bit = int(sample_rate / 10e6)  # 10Mbps
samples_per_bit
# Out:
# 125

# %%
ideal_packet_length = samples_per_bit*(8+148+4)*8
ideal_packet_length
# Out:
# 160000

# %% [markdown]
# ### Sequence Padding
# - longer packets are discarded

# %%
def length_standardization(extracted_signal, target_length=160000):
    """
    Standardizes signal to target_length. 
    Validates that the input is within a +/- 500 sample tolerance before padding.
    """
    current_len = len(extracted_signal)
    tolerance = 500 

    # 1. Check if it's too long
    if current_len > (target_length + tolerance):
        raise ValueError(f"Signal ({current_len}) exceeds target + tolerance.")

    # 2. Check if it's too short
    if current_len < (target_length - tolerance):
        raise ValueError(f"Signal ({current_len}) is below target - tolerance.")

    # 3. Standardize
    if current_len > target_length:
        # If within tolerance but slightly over, clip it
        return extracted_signal[:target_length]
    else:
        # If within tolerance but slightly under, pad it
        pad_size = target_length - current_len
        return np.pad(extracted_signal, (0, pad_size), mode='constant')

# %% [markdown]
# ### Extract Time domain Features

# %%
def extract_time_domain_features(signal):
    """Extract time-domain statistical features"""
    features = {}
    
    # Basic statistical moments
    features['std'] = np.std(signal)
    features['skewness'] = skew(signal)
    features['rms'] = np.sqrt(np.mean(signal**2))
    features['mean'] = np.mean(signal)
    features['kurtosis'] = kurtosis(signal)
    features['peak'] = np.max(np.abs(signal))
    
    # Shape factors
    features['shape_factor'] = features['rms'] / np.mean(np.abs(signal)) if np.mean(np.abs(signal)) != 0 else 0
    features['impulse_factor'] = features['peak'] / np.mean(np.abs(signal)) if np.mean(np.abs(signal)) != 0 else 0
    features['crest_factor'] = features['peak'] / features['rms'] if features['rms'] != 0 else 0
    features['clearance_factor'] = features['peak'] / (np.mean(np.sqrt(np.abs(signal)))**2) if np.mean(np.sqrt(np.abs(signal))) != 0 else 0
    
    return features

# %% [markdown]
# ### Extract Frequency domain features

# %%
def extract_frequency_domain_features(signal, fs):
    """Extract frequency-domain features"""
    # Compute FFT
    fft_signal = fft(signal)
    freqs = fftfreq(len(signal), 1/fs)
    
    # Get positive frequencies only
    positive_freq_idx = freqs > 0
    fft_positive = fft_signal[positive_freq_idx]
    freqs_positive = freqs[positive_freq_idx]
    
    # Find top 10 harmonic components
    magnitudes = np.abs(fft_positive)
    top_indices = np.argsort(magnitudes)[-10:]
    
    features = {}
    for i, idx in enumerate(top_indices):
        features[f'freq_mag_{i}'] = magnitudes[idx]
        features[f'freq_val_{i}'] = freqs_positive[idx]
    
    return features

# %% [markdown]
# ### Label Extracton from File Name

# %%
class ChannelCondition(Enum):
    NORMAL = 0
    AIR = 1
    WATER = 2
    TAPPED = 3

# %%
def extract_label_from_filename(filepath):
    filename = filepath.lower()

    # TYPE LABEL
    if 'air' in filename:
        anomaly_type = ChannelCondition.AIR.value
    elif 'water' in filename:
        anomaly_type = ChannelCondition.WATER.value
    elif 'tapped' in filename:
        anomaly_type = ChannelCondition.TAPPED.value
    else:
        anomaly_type = ChannelCondition.NORMAL.value  # normal

    # LENGTH / DISTANCE
    
    match = re.search(r'_(\d+(?:\.\d+)?)(cm|m)\.mat$', filename)

    if match:
        value = float(match.group(1))
        unit = match.group(2)

        if unit == 'm':
            value *= 100  # convert to cm

        anomaly_length = value
    else:
        anomaly_length = 0

    return anomaly_type, anomaly_length

# %%
# extract_label_from_filename(mat_file)

# %%
from pathlib import Path

root_dir = Path(r"E:\Thesis\thesis_code\data\oscilloscope\10Mbps")

for mat_file in root_dir.rglob("*.mat"):
    print(mat_file)
    print(extract_label_from_filename(str(mat_file)))
# Out:
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_10001_12500.mat
# (0, 0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_1_2500.mat
# (0, 0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_2501_5000.mat
# (0, 0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_5001_7500.mat
# (0, 0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_7501_10000.mat
# (0, 0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_10cm.mat
# (1, 10.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_15cm.mat
# (1, 15.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_20cm.mat
# (1, 20.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_25cm.mat
# (1, 25.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_30cm.mat
# (1, 30.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_35cm.mat
# (1, 35.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_40cm.mat
# (1, 40.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_45cm.mat
# (1, 45.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_50cm.mat
# (1, 50.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\air\ethernet_packets_1250_5cm.mat
# (1, 5.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_0.5m.mat
# (3, 50.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1.5m.mat
# (3, 150.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1m.mat
# (3, 100.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_2m.mat
# (3, 200.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_10cm.mat
# (2, 10.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_15cm.mat
# (2, 15.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_20cm.mat
# (2, 20.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_25cm.mat
# (2, 25.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_30cm.mat
# (2, 30.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_35cm.mat
# (2, 35.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_40cm.mat
# (2, 40.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_45cm.mat
# (2, 45.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_50cm.mat
# (2, 50.0)
# E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_5cm.mat
# (2, 5.0)

# %%
output_file = r'E:\Thesis\thesis_code\data\oscilloscope\10Mbps_features.h5'

# %%
def extract_features_from_mat_file(root_dir, output_file):
    
    with h5py.File(output_file, 'x') as out_f:

        feature_dim = 10 + 20  # 10 time + (10 mag + 10 freq)

        features_dset = out_f.create_dataset(
            'features',
            shape=(0, feature_dim),
            maxshape=(None, feature_dim),
            dtype='float32',
            chunks=True
        )

        labels_type = out_f.create_dataset(
            'label_type',
            shape=(0,),
            maxshape=(None,),
            dtype='int32',
            chunks=True
        )

        labels_length = out_f.create_dataset(
            'label_length',
            shape=(0,),
            maxshape=(None,),
            dtype='float32',
            chunks=True
        )

        current_size = 0

        for mat_file in root_dir.rglob("*.mat"):
            print(f"\nProcessing: {mat_file}")

            anomaly_type, anomaly_length = extract_label_from_filename(str(mat_file))

            with h5py.File(mat_file, 'r') as f:
                packets = f['packets']
                metadata = f['metadata']

                fs = metadata['sample_rate'][0][0]
                num_frames = packets.shape[0]

                batch_size = 100
                for i in range(0, num_frames, batch_size):
                    

                    try:
                        batch = packets[i:i+batch_size]  # lazy load
                        features_batch = []
                        types_batch = []
                        lengths_batch = []
                        for j, signal in enumerate(batch):
                            try:
                                # --- preprocessing ---
                                signal = extract_signal_region(signal)


                                signal = length_standardization(signal)

                                # --- feature extraction ---
                                time_feat = extract_time_domain_features(signal)
                                freq_feat = extract_frequency_domain_features(signal, fs)

                                # Combine features
                                combined = list(time_feat.values()) + list(freq_feat.values())
                                combined = np.array(combined, dtype=np.float32)

                                # --- store ---
                                # features_dset.resize(current_size + 1, axis=0)
                                # labels_type.resize(current_size + 1, axis=0)
                                # labels_length.resize(current_size + 1, axis=0)

                                # features_dset[current_size] = combined
                                # labels_type[current_size] = anomaly_type
                                # labels_length[current_size] = anomaly_length

                                features_batch.append(combined)
                                types_batch.append(anomaly_type)
                                lengths_batch.append(anomaly_length)
                            except Exception as e:
                                print(f"Skipping signal in frame {i+j}: {e}")
                                continue

                        # --- ONLY write valid samples ---
                        valid_count = len(features_batch)


                        if valid_count == 0:
                            continue

                        new_size = current_size + valid_count

                        features_dset.resize(new_size, axis=0)
                        labels_type.resize(new_size, axis=0)
                        labels_length.resize(new_size, axis=0)

                        features_dset[current_size:new_size] = features_batch
                        labels_type[current_size:new_size] = types_batch
                        labels_length[current_size:new_size] = lengths_batch

                        current_size = new_size

                    except Exception as e:
                        print(f"Skipping frame {i}: {e}")
                        continue

                    if i % 100 == 0:
                        print(f"Processed {i}/{num_frames} | Added {valid_count} samples")
                    # break
            # break
    print("\n✅ Feature extraction completed!")

# %%
# import cProfile
# cProfile.run('extract_features_from_mat_file(root_dir, output_file)')

# %%
extract_features_from_mat_file(root_dir, output_file)
# Out:
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\ethernet_packets_10001_12500.mat
# Skipping signal in frame 0: Signal (143) is below target - tolerance.
# Skipping signal in frame 1: Signal (142) is below target - tolerance.
# Skipping signal in frame 2: Signal (142) is below target - tolerance.
# Skipping signal in frame 31: Signal (162158) exceeds target + tolerance.
# Skipping signal in frame 32: Signal (199583) exceeds target + tolerance.
# Skipping signal in frame 33: Signal (228712) exceeds target + tolerance.
# Skipping signal in frame 34: Signal (202431) exceeds target + tolerance.
# Processed 0/2500 | Added 93 samples
# Skipping signal in frame 103: Signal (142) is below target - tolerance.
# Skipping signal in frame 104: Signal (142) is below target - tolerance.
# Skipping signal in frame 105: Signal (143) is below target - tolerance.
# Skipping signal in frame 106: Signal (143) is below target - tolerance.
# Skipping signal in frame 107: Signal (144) is below target - tolerance.
# Skipping signal in frame 194: Signal (249933) exceeds target + tolerance.
# Skipping signal in frame 195: Signal (249996) exceeds target + tolerance.
# Skipping signal in frame 196: Signal (249976) exceeds target + tolerance.
# Skipping signal in frame 197: Signal (249962) exceeds target + tolerance.
# Skipping signal in frame 198: Signal (249264) exceeds target + tolerance.
# Skipping signal in frame 199: Signal (249970) exceeds target + tolerance.
# Processed 100/1250 | Added 40 samples
# Skipping signal in frame 200: Signal (249986) exceeds target + tolerance.
# Skipping signal in frame 201: Signal (249755) exceeds target + tolerance.
# Skipping signal in frame 202: Signal (249980) exceeds target + tolerance.
# Skipping signal in frame 203: Signal (249695) exceeds target + tolerance.
# Skipping signal in frame 204: Signal (249234) exceeds target + tolerance.
# Skipping signal in frame 205: Signal (249196) exceeds target + tolerance.
# Skipping signal in frame 206: Signal (249686) exceeds target + tolerance.
# Skipping signal in frame 207: Signal (249888) exceeds target + tolerance.
# Skipping signal in frame 208: Signal (249975) exceeds target + tolerance.
# Skipping signal in frame 209: Signal (249966) exceeds target + tolerance.
# Skipping signal in frame 210: Signal (249897) exceeds target + tolerance.
# Skipping signal in frame 211: Signal (249537) exceeds target + tolerance.
# Skipping signal in frame 212: Signal (249970) exceeds target + tolerance.
# Skipping signal in frame 213: Signal (249994) exceeds target + tolerance.
# Skipping signal in frame 214: Signal (249836) exceeds target + tolerance.
# Skipping signal in frame 215: Signal (249970) exceeds target + tolerance.
# Skipping signal in frame 216: Signal (249983) exceeds target + tolerance.
# Skipping signal in frame 217: Signal (249994) exceeds target + tolerance.
# Skipping signal in frame 218: Signal (249970) exceeds target + tolerance.
# Skipping signal in frame 219: Signal (249797) exceeds target + tolerance.
# Skipping signal in frame 220: Signal (249978) exceeds target + tolerance.
# Skipping signal in frame 221: Signal (249910) exceeds target + tolerance.
# Skipping signal in frame 222: Signal (249748) exceeds target + tolerance.
# Skipping signal in frame 223: Signal (249962) exceeds target + tolerance.
# Skipping signal in frame 224: Signal (249988) exceeds target + tolerance.
# Skipping signal in frame 225: Signal (249721) exceeds target + tolerance.
# Skipping signal in frame 226: Signal (249986) exceeds target + tolerance.
# Skipping signal in frame 227: Signal (249888) exceeds target + tolerance.
# Skipping signal in frame 228: Signal (249960) exceeds target + tolerance.
# Skipping signal in frame 229: Signal (249962) exceeds target + tolerance.
# Skipping signal in frame 230: Signal (249249) exceeds target + tolerance.
# Skipping signal in frame 231: Signal (249988) exceeds target + tolerance.
# Skipping signal in frame 232: Signal (249914) exceeds target + tolerance.
# Skipping signal in frame 233: Signal (249161) exceeds target + tolerance.
# Skipping signal in frame 234: Signal (249981) exceeds target + tolerance.
# Skipping signal in frame 235: Signal (249993) exceeds target + tolerance.
# Processed 200/1250 | Added 64 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_0.5m.mat
# Skipping signal in frame 91: Signal (162378) exceeds target + tolerance.
# Skipping signal in frame 92: Signal (162318) exceeds target + tolerance.
# Skipping signal in frame 93: Signal (162125) exceeds target + tolerance.
# Skipping signal in frame 94: Signal (161851) exceeds target + tolerance.
# Processed 0/2500 | Added 96 samples
# Skipping signal in frame 100: Signal (187947) exceeds target + tolerance.
# Skipping signal in frame 101: Signal (161183) exceeds target + tolerance.
# Skipping signal in frame 102: Signal (163441) exceeds target + tolerance.
# Skipping signal in frame 103: Signal (161937) exceeds target + tolerance.
# Processed 100/2500 | Added 96 samples
# Processed 200/2500 | Added 100 samples
# Processed 300/2500 | Added 100 samples
# Processed 400/2500 | Added 100 samples
# Processed 500/2500 | Added 100 samples
# Processed 600/2500 | Added 100 samples
# Processed 700/2500 | Added 100 samples
# Processed 800/2500 | Added 100 samples
# Processed 900/2500 | Added 100 samples
# Processed 1000/2500 | Added 100 samples
# Processed 1100/2500 | Added 100 samples
# Processed 1200/2500 | Added 100 samples
# Processed 1300/2500 | Added 100 samples
# Processed 1400/2500 | Added 100 samples
# Processed 1500/2500 | Added 100 samples
# Processed 1600/2500 | Added 100 samples
# Processed 1700/2500 | Added 100 samples
# Processed 1800/2500 | Added 100 samples
# Processed 1900/2500 | Added 100 samples
# Processed 2000/2500 | Added 100 samples
# Processed 2100/2500 | Added 100 samples
# Processed 2200/2500 | Added 100 samples
# Processed 2300/2500 | Added 100 samples
# Processed 2400/2500 | Added 100 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1.5m.mat
# Skipping signal in frame 52: Signal (122148) is below target - tolerance.
# Skipping signal in frame 69: Signal (175010) exceeds target + tolerance.
# Skipping signal in frame 70: Signal (170070) exceeds target + tolerance.
# Skipping signal in frame 71: Signal (122211) is below target - tolerance.
# Processed 0/2500 | Added 96 samples
# Processed 100/2500 | Added 100 samples
# Processed 200/2500 | Added 100 samples
# Processed 300/2500 | Added 100 samples
# Processed 400/2500 | Added 100 samples
# Processed 500/2500 | Added 100 samples
# Processed 600/2500 | Added 100 samples
# Processed 700/2500 | Added 100 samples
# Processed 800/2500 | Added 100 samples
# Processed 900/2500 | Added 100 samples
# Processed 1000/2500 | Added 100 samples
# Processed 1100/2500 | Added 100 samples
# Processed 1200/2500 | Added 100 samples
# Processed 1300/2500 | Added 100 samples
# Processed 1400/2500 | Added 100 samples
# Processed 1500/2500 | Added 100 samples
# Processed 1600/2500 | Added 100 samples
# Processed 1700/2500 | Added 100 samples
# Processed 1800/2500 | Added 100 samples
# Processed 1900/2500 | Added 100 samples
# Processed 2000/2500 | Added 100 samples
# Processed 2100/2500 | Added 100 samples
# Processed 2200/2500 | Added 100 samples
# Processed 2300/2500 | Added 100 samples
# Processed 2400/2500 | Added 100 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_1m.mat
# Processed 0/2500 | Added 100 samples
# Processed 100/2500 | Added 100 samples
# Processed 200/2500 | Added 100 samples
# Processed 300/2500 | Added 100 samples
# Processed 400/2500 | Added 100 samples
# Processed 500/2500 | Added 100 samples
# Processed 600/2500 | Added 100 samples
# Processed 700/2500 | Added 100 samples
# Processed 800/2500 | Added 100 samples
# Processed 900/2500 | Added 100 samples
# Processed 1000/2500 | Added 100 samples
# Processed 1100/2500 | Added 100 samples
# Processed 1200/2500 | Added 100 samples
# Processed 1300/2500 | Added 100 samples
# Processed 1400/2500 | Added 100 samples
# Processed 1500/2500 | Added 100 samples
# Processed 1600/2500 | Added 100 samples
# Processed 1700/2500 | Added 100 samples
# Processed 1800/2500 | Added 100 samples
# Processed 1900/2500 | Added 100 samples
# Processed 2000/2500 | Added 100 samples
# Processed 2100/2500 | Added 100 samples
# Processed 2200/2500 | Added 100 samples
# Processed 2300/2500 | Added 100 samples
# Processed 2400/2500 | Added 100 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\tapped\ethernet_packets_2500_2m.mat
# Skipping signal in frame 0: Signal (155649) is below target - tolerance.
# Processed 0/2500 | Added 99 samples
# Processed 100/2500 | Added 100 samples
# Processed 200/2500 | Added 100 samples
# Processed 300/2500 | Added 100 samples
# Processed 400/2500 | Added 100 samples
# Processed 500/2500 | Added 100 samples
# Processed 600/2500 | Added 100 samples
# Processed 700/2500 | Added 100 samples
# Processed 800/2500 | Added 100 samples
# Processed 900/2500 | Added 100 samples
# Processed 1000/2500 | Added 100 samples
# Processed 1100/2500 | Added 100 samples
# Processed 1200/2500 | Added 100 samples
# Processed 1300/2500 | Added 100 samples
# Processed 1400/2500 | Added 100 samples
# Processed 1500/2500 | Added 100 samples
# Processed 1600/2500 | Added 100 samples
# Processed 1700/2500 | Added 100 samples
# Processed 1800/2500 | Added 100 samples
# Processed 1900/2500 | Added 100 samples
# Processed 2000/2500 | Added 100 samples
# Processed 2100/2500 | Added 100 samples
# Processed 2200/2500 | Added 100 samples
# Processed 2300/2500 | Added 100 samples
# Processed 2400/2500 | Added 100 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_10cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_15cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_20cm.mat
# Skipping signal in frame 75: Signal (207084) exceeds target + tolerance.
# Processed 0/1250 | Added 99 samples
# Processed 100/1250 | Added 100 samples
# Skipping signal in frame 244: Signal (167240) exceeds target + tolerance.
# Skipping signal in frame 246: Signal (214693) exceeds target + tolerance.
# Skipping signal in frame 247: Signal (193206) exceeds target + tolerance.
# Processed 200/1250 | Added 97 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_25cm.mat
# Skipping signal in frame 0: Signal (119939) is below target - tolerance.
# Processed 0/1250 | Added 99 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_30cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_35cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_40cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_45cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_50cm.mat
# Processed 0/1250 | Added 100 samples
# Processed 100/1250 | Added 100 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# Processing: E:\Thesis\thesis_code\data\oscilloscope\10Mbps\water\ethernet_packets_1250_5cm.mat
# Processed 0/1250 | Added 100 samples
# Skipping signal in frame 187: Signal (162915) exceeds target + tolerance.
# Processed 100/1250 | Added 99 samples
# Processed 200/1250 | Added 100 samples
# Processed 300/1250 | Added 100 samples
# Processed 400/1250 | Added 100 samples
# Processed 500/1250 | Added 100 samples
# Processed 600/1250 | Added 100 samples
# Processed 700/1250 | Added 100 samples
# Processed 800/1250 | Added 100 samples
# Processed 900/1250 | Added 100 samples
# Processed 1000/1250 | Added 100 samples
# Processed 1100/1250 | Added 100 samples
# Processed 1200/1250 | Added 50 samples
#
# ✅ Feature extraction completed!
